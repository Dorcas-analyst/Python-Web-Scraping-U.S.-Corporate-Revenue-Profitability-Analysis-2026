# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://grokipedia.com/page/List_of_largest_companies_in_the_United_States_by_revenue"

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="dark" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, interactive-widget=resizes-content" name="viewport"/>
#   <title>
#    List of largest companies in the United States by revenue â Grokipedia
#   </title>
#   <meta content="The list of largest companies in the United States by revenue is an annual ranking published by Fortune magazine, featuring the top 500 U.S.-headquartered corporations ordered by total revenue generat" name="description"/>
#   <link href="https://grokipedia.com/page/List_of_largest_companies_in_the_United_States_by_revenue" rel="canonical"/>
#   <link href="/favicon.ico" rel="icon" sizes="48x48"/>
#   <link href="/icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="/icon-512x512.png" rel="icon" sizes="512x512" type="image/png"/>
#   <link href="/icon-192x192.png" rel="apple-touch-icon"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <!-- OG -->
#   <meta content="List of largest companies in the United States by revenue â Grokipedia" property="og:title"/>
#   <meta content="The list of largest companies in the United States by revenue is an annual ranking published by Fortune magazine, featuring the top 500 U.S.-headquartered corporations ordered by total revenue generat" property="og:description"/>
#   <meta content="https://grokipedia.com/page/List_of_largest_companies_in_the_United_States_by_revenue" property="og:url"/>
#   <meta content="Grokipedia" property="og:site_name"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="article" property="og:type"/>
#   <meta content="https://grokipedia.com/icon-512x512.png" property="og:image"/>
#   <meta content="512" property="og:image:width"/>
#   <meta content="512" property="og:image:height"/>
#   <meta content="Grokipedia" property="og:image:alt"/>
#   <!-- Twitter -->
#   <meta content="summary" name="twitter:card"/>
#   <meta content="@Grokipedia" name="twitter:creator"/>
#   <meta content="List of largest companies in the United States by revenue â Grokipedia" name="twitter:title"/>
#   <meta content="The list of largest companies in the United States by revenue is an annual ranking published by Fortune magazine, featuring the top 500 U.S.-headquartered corporations ordered by total revenue generat" name="twitter:description"/>
#   <meta content="https://grokipedia.com/icon-512x512.png" name="twitter:image"/>
#   <!-- Robots -->
#   <meta content="index, follow" name="robots"/>
#   <meta content="index, follow, max-snippet:-1" name="googlebot"/>
#   <!-- Schema.org WebSite structured data (for sitelinks search box) -->
#   <!-- Theme: apply synchronously before first paint to prevent flash -->
#   <script nonce="9Y/jJR93aRXgpMCoBIpWeg==">
#    (function(){
#         var t = localStorage.getItem('theme');
#         if (t === 'light') document.documentElement.classList.remove('dark');
#         else if (t === 'dark') document.documentElement.classList.add('dark');
#         else {
#           // system preference
#           if (window.matchMedia('(prefers-color-scheme: light)').matches) {
#             document.documentElement.classList.remove('dark');
#           } else {
#             document.documentElement.classList.add('dark');
#           }
#         }
#       })();
#   </script>
#   <!-- KaTeX CSS for server-rendered math (loaded from CDN, fonts only) -->
#   <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/katex@0.16.21/dist/katex.min.css" rel="stylesheet"/>
#   <link href="/_astro/activity.Clg-wNwt.css" rel="stylesheet"/>
#   <link href="/_astro/activity.B8hnKYSI.css" rel="stylesheet"/>
#  </head>
#  <body class="flex h-[100svh] w-full flex-col bg-surface-base text-fg-primary antialiased" data-auth="0">
#   <!-- Analytics: UAS + page views + action events (~400 bytes gzipped) -->
#   <script nonce="9Y/jJR93aRXgpMCoBIpWeg==">
#    (function(){
#       var t0=Date.now(),active=0,idle=false,last=t0,thr=0;
#       var mob=window.innerWidth<768?1:0;
#       var auth=document.body.getAttribute('data-auth')==='1'?1:0;
#
#       // Referrer classification (bucketed to avoid cardinality explosion)
#       var ref=document.referrer,r='direct';
#       if(ref){try{var h=new URL(ref).hostname;
#         if(/google\./i.test(h))r='google';
#         else if(/bing\./i.test(h))r='bing';
#         else if(/duckduckgo\./i.test(h))r='duckduckgo';
#         else if(/x\.com|twitter\.com/i.test(h))r='x';
#         else if(/reddit\.com/i.test(h))r='reddit';
#         else if(/claude\.ai|anthropic/i.test(h))r='claude';
#         else if(/chatgpt\.com|openai/i.test(h))r='chatgpt';
#         else if(/grokipedia\.com/i.test(h))r='internal';
#         else r='other';
#       }catch(e){r='other';}}
#
#       // Browser language (primary, 2-letter code)
#       var lang=(navigator.language||'').slice(0,2).toLowerCase()||'unknown';
#
#       function tick(){
#         var n=Date.now();
#         if(n-thr<200)return;thr=n;
#         if(!idle)active+=n-last;
#         last=n;idle=false;
#       }
#       document.addEventListener('visibilitychange',function(){
#         if(document.hidden){tick();idle=true;}else{last=Date.now();idle=false;}
#       });
#       ['click','scroll','keydown','touchstart'].forEach(function(e){
#         document.addEventListener(e,tick,{passive:true,capture:true});
#       });
#       addEventListener('pagehide',function(){
#         tick();
#         var p=location.pathname,s=p.indexOf('/page/')===0?p.slice(6):p;
#         var perf=performance.getEntriesByType&&performance.getEntriesByType('navigation');
#         var lt=perf&&perf[0]?perf[0].loadEventEnd/1000:0;
#         // Auto-translate detection: Chrome/Edge add class "translated-*" and change html lang
#         var docLang=document.documentElement.lang||'';
#         var translated=(docLang&&docLang!=='en'&&
#           document.documentElement.className.indexOf('translated')!==-1)?docLang:'';
#         navigator.sendBeacon('/api/analytics',new Blob([JSON.stringify({
#           s:s,p:p,a:Math.round(active/1000),d:Math.round((Date.now()-t0)/1000),
#           l:Math.round(lt*100)/100,u:auth,m:mob,
#           r:r,lang:lang,translated:translated
#         })],{type:'application/json'}));
#       });
#       // Global event tracker for discrete actions
#       window.__ev=function(e,q){
#         navigator.sendBeacon('/api/ev',new Blob([JSON.stringify({e:e,q:q||'',m:mob})],{type:'application/json'}));
#       };
#     })();
#   </script>
#   <script nonce="9Y/jJR93aRXgpMCoBIpWeg==" type="application/ld+json">
#    {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Grokipedia","item":"https://grokipedia.com"},{"@type":"ListItem","position":2,"name":"List of largest companies in the United States by revenue","item":"https://grokipedia.com/page/List_of_largest_companies_in_the_United_States_by_revenue"}]}
#   </script>
#   <script nonce="9Y/jJR93aRXgpMCoBIpWeg==" type="application/ld+json">
#    {"@context":"https://schema.org","@type":"Article","headline":"List of largest companies in the United States by revenue","url":"https://grokipedia.com/page/List_of_largest_companies_in_the_United_States_by_revenue","publisher":{"@type":"Organization","name":"Grokipedia","url":"https://grokipedia.com"},"dateModified":"2026-01-14T01:23:59.000Z"}
#   </script>
#   <header class="bg-surface-base fixed top-0 z-50 h-16 w-full">
#    <!-- Desktop Header (md+) â matches Next.js grid-cols-[1fr_3fr_1fr] -->
#    <div class="hidden h-full w-full grid-cols-[1fr_3fr_1fr] items-center gap-4 !py-0 md:grid max-w-screen-3xl mx-auto px-4 py-6 sm:px-6">
#     <!-- Logo -->
fill="none" stroke="currentColor" stroke-width="2" viewbox="0 0 24 24">
#        <circle cx="11" cy="11" r="8">
#        </circle>
#        <path d="m21 21-4.35-4.35">
#        </path>
#       </svg>
#       <span class="flex-1">
#        Search
#       </span>
#       <kbd class="rounded border border-border-l2 bg-surface-l2 px-1.5 py-0.5 text-[11px] font-medium text-fg-tertiary">
#        âK
#       </kbd>
#      </a>
#     </div>
#     <!-- Right side: theme toggle + suggest article + user menu -->
#     <div class="flex items-center gap-2 justify-self-end">
#      <!-- Theme toggle -->
#      <button aria-label="Toggle theme" class="flex h-9 w-9 flex-shrink-0 items-center justify-center rounded-full text-fg-secondary transition hover:bg-surface-l1" id="theme-toggle-desktop">
#       <svg class="hidden h-5 w-5 dark:block" fill="none" stroke="currentColor" stroke-width="2" viewbox="0 0 24 24">
#        <circle cx="12" cy="12" r="5">
#        </circle>
#        <path d="M12 1v2M12 21v2M4.22 4.22l1.42 1.42M18.36 18.36l1.42 1.42M1 12h2M21 12h2M4.22 19.78l1.42-1.42M18.36 5.64l1.42-1.42">
#        </path>
#       </svg>
#       <svg class="block h-5 w-5 dark:hidden" fill="none" stroke="currentColor" stroke-width="2" viewbox="0 0 24 24">
#        <path d="M21 12.79A9 9 0 1 1 11.21 3 7 7 0 0 0 21 12.79z">
#        </path>
#       </svg>
#      </button>
#      <button class="border-border-l2 flex items-center gap-1.5 whitespace-nowrap rounded-full border bg-surface-l1 px-4 py-1.5 text-sm font-medium text-fg-primary transition hover:bg-surface-l2" id="header-suggest-btn" type="button">
#       Suggest Edit
#      </button>
#      <a class="rounded-full bg-fg-primary px-4 py-1.5 text-sm font-medium text-surface-base transition hover:opacity-90" href="https://accounts.x.ai/check-login?redirect=grokipedia-com&amp;return_to=%2Fpage%2FList_of_largest_companies_in_the_United_States_by_revenue">
#       Sign in
#      </a>
#     </div>
#    </div>
#    <!-- Mobile Header (<md) â matches Next.js flex layout -->
#    <div class="flex h-full w-full items-center justify-between md:hidden max-w-screen-3xl mx-auto px-4 py-6 sm:px-6 pt-8">
#     <!-- Left: Logo -->
#     <div class="flex items-center gap-1">
#      <a class="cursor-pointer" href="/">
#       <svg aria-label="Grokipedia" class="" fill="none" viewbox="0 0 786 179" width="140" xmlns="http://www.w3.org/2000/svg">
#        <path d="M54.272 123.92C44.6293 123.92 36.224 122.128 29.056 118.544C21.888 114.96 16.2987 109.755 12.288 102.928C8.36267 96.1013 6.4 87.9093 6.4 78.352C6.4 68.7947 8.36267 60.4747 12.288 53.392C16.2987 46.3093 21.888 40.8053 29.056 36.88C36.3093 32.9547 44.8 30.992 54.528 30.992C57.7707 30.992 61.2267 31.248 64.896 31.76C68.5653 32.1867 71.7227 32.784 74.368 33.552C75.9893 33.9787 77.4827 34.3627 78.848 34.704C80.2133 35.0453 81.5787 35.216 82.944 35.216C83.968 35.216 84.992 35.088 86.016 34.832C86.1867 38.5867 86.3573 42.4693 86.528 46.48C86.6987 50.4907 86.9547 54.672 87.296 59.024C85.504 59.28 84.0107 59.3653 82.816 59.28C81.1093 51.4293 77.9947 45.6267 73.472 41.872C68.9493 38.032 62.9333 36.112 55.424 36.112C49.4507 36.112 44.3307 37.2213 40.064 39.44C35.8827 41.5733 32.4693 44.5173 29.824 48.272C27.264 52.
 79.448 714.543 79.448ZM737.26 122.864C735.772 122.864 734.572 122.384 733.66 121.424C732.796 120.464 732.364 119.312 732.364 117.968C732.364 116.384 732.916 115.04 734.02 113.936C735.172 112.784 736.564 112.208 738.196 112.208C739.684 112.208 740.836 112.664 741.652 113.576C742.516 114.488 742.948 115.64 742.948 117.032C742.948 118.616 742.42 119.984 741.364 121.136C740.308 122.288 738.94 122.864 737.26 122.864ZM757.202 85.064C757.01 84.824 756.794 84.584 756.554 84.344C756.314 84.056 756.074 83.72 755.834 83.336C758.138 80.984 760.562 79.28 763.106 78.224C765.65 77.168 768.17 76.64 770.666 76.64C774.506 76.64 777.506 77.672 779.666 79.736C781.826 81.8 782.906 84.344 782.906 87.368C782.906 89.72 782.234 92.072 780.89 94.424C779.594 96.728 777.77 99.056 775.418 101.408C773.066 103.712 770.354 106.088 767.282 108.536C764.21 110.936 760.922 113.432 757.418 116.024L769.442 115.952C771.602 115.952 773.282 115.856 774.482 115.664C775.73 115.472 776.786 114.92 777.65 114.008C778.562 113.096 779.57 111.608 780.674 109.544C781.058 109.544 781.442 109.544 781.826 109.544C782.258 109.544 782.69 109.592 783.122 109.688C782.066 112.568 781.25 114.968 780.674 116.888C780.146 118.808 779.642 120.536 779.162 122.072C777.194 122.024 775.034 122 772.682 122C770.33 121.952 767.978 121.928 765.626 121.928C763.322 121.928 761.21 121.928 759.29 121.928C756.554 121.928 754.274 121.928 752.45 121.928C750.674 121.928 749.282 121.952 748.274 122C748.13 121.328 748.058 120. ...
#        </path>
#       </svg>
#      </a>
#     </div>
#     <!-- Right: Auth + Search + Theme -->
#     <div class="flex items-center gap-1">
#      <a class="rounded-full bg-fg-primary px-3 py-1 text-xs font-medium text-surface-base transition hover:opacity-90" href="https://accounts.x.ai/check-login?redirect=grokipedia-com&amp;return_to=%2Fpage%2FList_of_largest_companies_in_the_United_States_by_revenue">
#       Sign in
#      </a>
#      <a aria-label="Search" class="flex h-9 w-9 items-center justify-center rounded-full text-fg-secondary transition hover:bg-surface-l1" href="/search">
#       <svg class="h-5 w-5" fill="none" stroke="currentColor" stroke-width="2" viewbox="0 0 24 24">
#        <circle cx="11" cy="11" r="8">
#        </circle>
#        <path d="m21 21-4.35-4.35">
#        </path>
#       </svg>
#      </a>
#      <button aria-label="Toggle theme" class="flex h-9 w-9 flex-shrink-0 items-center justify-center rounded-full text-fg-secondary transition hover:bg-surface-l1" id="theme-toggle-mobile">
#       <svg class="hidden h-5 w-5 dark:block" fill="none" stroke="currentColor" stroke-width="2" viewbox="0 0 24 24">
#        <circle cx="12" cy="12" r="5">
#        </circle>
#        <path d="M12 1v2M12 21v2M4.22 4.22l1.42 1.42M18.36 18.36l1.42 1.42M1 12h2M21 12h2M4.22 19.78l1.42-1.42M18.36 5.64l1.42-1.42">
#        </path>
#       </svg>
#       <svg class="block h-5 w-5 dark:hidden" fill="none" stroke="currentColor" stroke-width="2" viewbox="0 0 24 24">
#        <path d="M21 12.79A9 9 0 1 1 11.21 3 7 7 0 0 0 21 12.79z">
#        </path>
#       </svg>
#      </button>
#     </div>
#    </div>
#   </header>
#   <script nonce="9Y/jJR93aRXgpMCoBIpWeg==">
#    function toggleTheme() {
#     var html = document.documentElement;
#     var isDark = html.classList.contains('dark');
#     if (isDark) {
#       html.classList.remove('dark');
#       localStorage.setItem('theme', 'light');
#     } else {
#       html.classList.add('dark');
#       localStorage.setItem('theme', 'dark');
#     }
#   }
#   document.getElementById('theme-toggle-desktop')?.addEventListener('click', toggleTheme);
#   document.getElementById('theme-toggle-mobile')?.addEventListener('click', toggleTheme);
#
#   // âK shortcut to open search
#   document.addEventListener('keydown', function(e) {
#     if ((e.metaKey || e.ctrlKey) && e.key === 'k') {
#       e.preventDefault();
#       var link = document.getElementById('header-search-link');
#       if (link) link.click();
#       else window.location.href = '/search';
#     }
#   });
#
#   document.getElementById('header-suggest-btn')?.addEventListener('click', function() {
#     if (window.__openContributeModal) window.__openContributeModal({ mode: this.textContent === 'Suggest Edit' ? 'edit' : 'article' });
#     else if (window.__openSuggestArticle) window.__openSuggestArticle();
#   });
#
#   // User menu dropdown
#   var umBtn = document.getElementById('user-menu-btn');
#   var umMenu = document.getElementById('user-menu');
#   var umWrap = document.getElementById('user-menu-wrap');
#   if (umBtn && umMenu) {
#     umBtn.addEventListener('click', function() { umMenu.classList.toggle('hidden'); });
#     document.addEventListener('click', function(e) {
#       if (umWrap && !umWrap.contains(e.target)) umMenu.classList.add('hidden');
#     });
#   }
#   </script>
#   <main class="relative xl:flex xl:gap-0">
#    <!-- Left sidebar: Table of Contents (360px, matches Next.js) -->
#    <aside class="sticky top-16 hidden h-[calc(100vh-4rem)] w-[360px] shrink-0 overflow-hidden xl:block" id="toc-sidebar">
#     <nav class="bg-surface-base h-full w-[360px] overflow-y-auto px-6 pb-32 pt-8 scrollbar-none [-ms-overflow-style:none] [scrollbar-width:none] [&amp;::-webkit-scrollbar]:hidden [overscroll-behavior:contain]" id="toc-nav">
#      <ul class="space-y-2 text-sm">
#       <li class="toc-item flex items-start gap-2 overflow-hidden" data-toc-depth="2" data-toc-id="current-public-rankings" style="padding-left: 0.75rem">
#        <div class="toc-dot bg-foreground mt-[0.5rem] h-1 w-1 flex-shrink-0 transition-opacity opacity-0">
#        </div>
#        <a class="toc-link transition-opacity hover:opacity-100 opacity-50" href="#current-public-rankings">
#         Current Public Rankings
#        </a>
#       </li>
#       <li class="toc-item flex items-start gap-2 overflow-hidden" data-toc-depth="3" data-toc-id="top-100-by-revenue-2025" style="padding-left: 1.5rem">
#        <div class="toc-dot bg-foreground mt-[0.5rem] h-1 w-1 flex-shrink-0 transition-opacity opacity-0">
#        </div>
#        <a class="toc-link transition-opacity hover:opacity-100 opacity-50" href="#top-100-by-revenue-2025">
#         Top 100 by Revenue (2025)
#        </a>
#       </li>
#       <li class="toc-item flex items-start gap-2 overflow-hidden" data-toc-depth="3" data-toc-id="top-50-by-profit-2025" style="padding-left: 1.5rem">
#        <div class="toc-dot bg-foreground mt-[0.5rem] h-1 w-1 flex-shrink-0 transition-opacity opacity-0">
#        </div>
#        <a class="toc-link transition-opacity hover:opacity-100 opacity-50" href="#top-50-by-profit-2025">
#         Top 50 by Profit (2025)
#        </a>
#       </li>
#       <li class="toc-item flex items-start gap-2 overflow-hidden" data-toc-depth="2" data-toc-id="current-private-rankings" style="padding-left: 0.75rem">
#        <div class="toc-dot bg-foreground mt-[0.5rem] h-1 w-1 flex-shrink-0 transition-opacity opacity-0">
#        </div>
#        <a class="toc-link transition-opacity hover:opacity-100 opacity-50" href="#current-private-rankings">
#         Current Private Rankings
#        </a>
#       </li>
#       <li class="toc-item flex items-start gap-2 overflow-hidden" data-toc-depth="3" data-toc-id="top-50-by-revenue-2024" style="padding-left: 1.5rem">
#        <div class="toc-dot bg-foreground mt-[0.5rem] h-1 w-1 flex-shrink-0 transition-opacity opacity-0">
#        </div>
#        <a class="toc-link transition-opacity hover:opacity-100 opacity-50" href="#top-50-by-revenue-2024">
#         Top 50 by Revenue (2024)
#        </a>
#       </li>
#       <li class="toc-item flex items-start gap-2 overflow-hidden" data-toc-depth="3" data-toc-id="sector-breakdown-of-private-leaders" style="padding-left: 1.5rem">
#        <div class="toc-dot bg-foreground mt-[0.5rem] h-1 w-1 flex-shrink-0 transition-opacity opacity-0">
#        </div>
#        <a class="toc-link transition-opacity hover:opacity-100 opacity-50" href="#sector-breakdown-of-private-leaders">
#         Sector Breakdown of Private Leaders
#        </a>
#       </li>
#       <li class="toc-item flex items-start gap-2 overflow-hidden" data-toc-depth="2" data-toc-id="historical-and-comparative-analysis" style="padding-left: 0.75rem">
#        <div class="toc-dot bg-foreground mt-[0.5rem] h-1 w-1 flex-shrink-0 transition-opacity opacity-0">
#        </div>
#        <a class="toc-link transition-opacity hover:opacity-100 opacity-50" href="#historical-and-comparative-analysis">
#         Historical and Comparative Analysis
#        </a>
#       </li>
#       <li class="toc-item flex items-start gap-2 overflow-hidden" data-toc-depth="3" data-toc-id="evolution-of-revenue-leaders-19552025" style="padding-left: 1.5rem">
#        <div class="toc-dot bg-foreground mt-[0.5rem] h-1 w-1 flex-shrink-0 transition-opacity opacity-0">
#        </div>
#        <a class="toc-link transition-opacity hover:opacity-100 opacity-50" href="#evolution-of-revenue-leaders-19552025">
#         Evolution of Revenue Leaders (1955â2025)
#        </a>
#       </li>
#       <li class="toc-item flex items-start gap-2 overflow-hidden" data-toc-depth="3" data-toc-id="notable-shifts-and-trends" style="padding-left: 1.5rem">
#        <div class="toc-dot bg-foreground mt-[0.5rem] h-1 w-1 flex-shrink-0 transition-opacity opacity-0">
#        </div>
#        <a class="toc-link transition-opacity hover:opacity-100 opacity-50" href="#notable-shifts-and-trends">
#         Notable Shifts and Trends
#        </a>
#       </li>
#       <li class="toc-item flex items-start gap-2 overflow-hidden" data-toc-depth="2" data-toc-id="references" style="padding-left: 0.75rem">
#        <div class="toc-dot bg-foreground mt-[0.5rem] h-1 w-1 flex-shrink-0 transition-opacity opacity-0">
#        </div>
#        <a class="toc-link transition-opacity hover:opacity-100 opacity-50" href="#references">
#         References
#        </a>
#       </li>
#      </ul>
#     </nav>
#    </aside>
#    <script nonce="9Y/jJR93aRXgpMCoBIpWeg==">
#     (function() {
#   var nav = document.getElementById('toc-nav');
#   var items = document.querySelectorAll('.toc-item');
#   if (!items.length || !nav) return;
#
#   var activeId = null;
#   var headerOffset = 96;
#   var isUserScrolling = false;
#   var scrollTimeout = null;
#
#   function setActive(id) {
#     if (id === activeId) return;
#     activeId = id;
#     for (var i = 0; i < items.length; i++) {
#       var item = items[i];
#       var dot = item.querySelector('.toc-dot');
#       var link = item.querySelector('.toc-link');
#       var isActive = item.dataset.tocId === id;
#       if (dot) dot.style.opacity = isActive ? '1' : '0';
#       if (link) {
#         link.style.opacity = isActive ? '1' : '0.5';
#         link.style.textShadow = isActive ? '0.2px 0 0 currentColor' : 'none';
#       }
#       // Show/hide subsections (depth > 2)
#       var depth = parseInt(item.dataset.tocDepth, 10);
#       if (depth > 2) {
#         var shouldShow = false;
#         // Find parent section
#         var parentIdx = -1;
#         for (var j = i - 1; j >= 0; j--) {
#           if (parseInt(items[j].dataset.tocDepth, 10) <= 2) { parentIdx = j; break; }
#         }
#         if (parentIdx >= 0) {
#           var parentId = items[parentIdx].dataset.tocId;
#           if (activeId === parentId || activeId === item.dataset.tocId) shouldShow = true;
#           // Check siblings in same group
#           if (!shouldShow) {
#             for (var k = parentIdx + 1; k < items.length; k++) {
#               if (parseInt(items[k].dataset.tocDepth, 10) <= 2) break;
#               if (activeId === items[k].dataset.tocId) { shouldShow = true; break; }
#             }
#           }
#         }
#         item.style.display = shouldShow ? '' : 'none';
#       }
#     }
#     // Auto-scroll active item into view
#     var activeItem = document.querySelector('.toc-item[data-toc-id="' + id + '"]');
#     if (activeItem) {
#       var itemTop = activeItem.offsetTop;
#       var itemHeight = activeItem.offsetHeight;
#       var navScrollTop = nav.scrollTop;
#       var navHeight = nav.clientHeight;
#       var isAbove = itemTop < navScrollTop + 80;
#       var isBelow = itemTop + itemHeight > navScrollTop + navHeight - 80;
#       if (isAbove || isBelow) {
#         nav.scrollTo({ top: isBelow ? itemTop + itemHeight - navHeight + 80 : itemTop - 80, behavior: 'smooth' });
#       }
#     }
#   }
#
#   function findActiveHeading() {
#     var headings = document.querySelectorAll('h1[id], h2[id], h3[id], h4[id], h5[id], h6[id]');
#     var threshold = headerOffset + 300;
#     var last = null;
#     for (var i = 0; i < headings.length; i++) {
#       if (headings[i].getBoundingClientRect().top <= threshold) last = headings[i].id;
#     }
#     // Check references section too
#     var refs = document.getElementById('references');
#     if (refs && refs.getBoundingClientRect().top <= threshold) last = 'references';
#     return last || (headings.length ? headings[0].id : null);
#   }
#
#   var throttle = null;
#   window.addEventListener('scroll', function() {
#     if (isUserScrolling) return;
#     if (throttle) return;
#     throttle = setTimeout(function() {
#       throttle = null;
#       var id = findActiveHeading();
#       if (id) setActive(id);
#     }, 100);
#   }, { passive: true });
#
#   // Handle TOC clicks â smooth scroll to heading
#   for (var i = 0; i < items.length; i++) {
#     (function(item) {
#       var link = item.querySelector('.toc-link');
#       if (!link) return;
#       link.addEventListener('click', function(e) {
#         e.preventDefault();
#         var id = item.dataset.tocId;
#         var el = document.getElementById(id);
#         if (!el) return;
#         isUserScrolling = true;
#         if (scrollTimeout) clearTimeout(scrollTimeout);
#         var top = el.getBoundingClientRect().top + window.scrollY - headerOffset;
#         window.scrollTo({ top: top });
#         history.replaceState(null, '', '#' + id);
#         setActive(id);
#         if ('onscrollend' in window) {
#           window.addEventListener('scrollend', function fn() { isUserScrolling = false; window.removeEventListener('scrollend', fn); }, { once: true });
#         } else {
#           scrollTimeout = setTimeout(function() { isUserScrolling = false; }, 500);
#         }
#       });
#     })(items[i]);
#   }
#
#   // Init: hide all depth > 2 items, set first as active
#   for (var i = 0; i < items.length; i++) {
#     if (parseInt(items[i].dataset.tocDepth, 10) > 2) items[i].style.display = 'none';
#   }
#   // Check hash first
#   var hash = window.location.hash.slice(1);
#   if (hash) { setActive(hash); }
#   else {
#     var id = findActiveHeading();
#     if (id) setActive(id);
#   }
# })();
#    </script>
#    <!-- Markdown â Centered Column -->
#    <div class="relative top-16 min-w-0 flex-1 pb-32 pt-8 px-4 md:px-8">
#     <div class="mx-auto max-w-[900px] xl:max-w-[1400px] xl:px-6">
#      <!-- Last updated badge -->
#      <div class="mb-2 flex items-center gap-2 text-sm text-fg-tertiary">
#       <svg class="h-4 w-4 shrink-0" fill="currentColor" viewbox="0 0 33 33">
#        <path d="M13.237 21.041l11.082-8.19a.75.75 0 0 1 1.578.379c1.363 3.289.754 7.242-1.957 9.955-2.71 2.714-6.482 3.31-9.93 1.954l-3.765 1.745c5.401 3.697 11.96 2.783 16.059-1.324 3.25-3.255 4.258-7.692 3.316-11.693l.009.008C27.965 7.998 29.666 5.65 33.15.845 33.232.73 33.314.617 33.397.5l-4.586 4.59v-.014L13.234 21.044z">
#        </path>
#        <path d="M10.95 23.031c-3.877-3.707-3.208-9.446.1-12.755 2.446-2.45 6.454-3.449 9.952-1.98l3.758-1.737a12.5 12.5 0 0 0-2.54-1.386c-4.5-1.854-9.887-.931-13.545 2.728-3.518 3.523-4.625 8.94-2.725 13.561 1.42 3.454-.906 5.898-3.25 8.363-.83.874-1.664 1.749-2.335 2.674L10.947 23.034z">
#        </path>
#       </svg>
#       <span>
#        Fact-checked by Grok 6 months ago
#       </span>
#      </div>
#      <article class="text-[16px]">
#       <div class="flow-root">
#        <!-- Title row with copy-link action (matches Next.js titleAction) -->
#        <div class="mb-4 flex flex-col gap-2 sm:flex-row sm:items-start sm:justify-between sm:gap-4">
#         <div class="min-w-0 flex-1">
#          <h1 class="group relative mb-0 mt-0 scroll-mt-24 font-serif text-[2.125em] font-semibold tracking-[-1px]" id="List_of_largest_companies_in_the_United_States_by_revenue">
#           List of largest companies in the United States by revenue
#          </h1>
#         </div>
#         <div class="shrink-0">
#          <div class="flex items-center gap-1">
#           <!-- Listen button (rendered inline in the article header) -->
#           <button aria-label="Listen to this article" class="text-fg-secondary hover:text-fg-primary flex h-8 w-8 cursor-pointer items-center justify-center rounded-full transition hover:bg-surface-l2" data-slug="List_of_largest_companies_in_the_United_States_by_revenue" id="tts-listen-btn" title="Listen" type="button">
#            <svg class="h-5 w-5" fill="none" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24">
#             <polygon points="11 5 6 9 2 9 2 15 6 15 11 19 11 5">
#             </polygon>
#             <path d="M15.54 8.46a5 5 0 0 1 0 7.07">
#             </path>
#             <path d="M19.07 4.93a10 10 0 0 1 0 14.14">
#             </path>
#            </svg>
#           </button>
#           <!-- Floating player (hidden until playback starts) -->
#           <div class="fixed bottom-6 left-1/2 z-50 -translate-x-1/2 hidden" id="tts-player" style="max-width:calc(100vw - 2rem)">
#            <div class="border-border-l2 flex items-center gap-2 rounded-full border bg-surface-l2 px-3 py-1.5 shadow-lg backdrop-blur dark:border-white/15 dark:bg-neutral-700/95 dark:text-white sm:gap-3 sm:px-4 sm:py-2">
#             <!-- Play/Pause -->
#             <button aria-label="Play" class="flex h-10 w-10 shrink-0 items-center justify-center rounded-full text-fg-secondary transition hover:bg-surface-l3 dark:text-white/80 dark:hover:bg-white/10" id="tts-playpause" type="button">
#              <svg class="h-5 w-5" fill="currentColor" id="tts-icon-play" viewbox="0 0 24 24">
#               <path d="M7 5.5c0-.9.98-1.45 1.73-.97l9 5.5c.72.44.72 1.5 0 1.95l-9 5.5c-.75.46-1.73-.07-1.73-.97v-11.1z">
#               </path>
#              </svg>
#              <svg class="h-5 w-5 hidden" fill="currentColor" id="tts-icon-pause" viewbox="0 0 24 24">
#               <rect height="14" rx="1.5" width="4" x="6" y="5">
#               </rect>
#               <rect height="14" rx="1.5" width="4" x="14" y="5">
#               </rect>
#              </svg>
#              <svg class="h-5 w-5 hidden animate-spin" fill="none" id="tts-icon-spinner" viewbox="0 0 24 24">
#               <circle cx="12" cy="12" opacity="0.25" r="10" stroke="currentColor" stroke-width="3">
#               </circle>
#               <path d="M12 2a10 10 0 0 1 10 10" stroke="currentColor" stroke-linecap="round" stroke-width="3">
#               </path>
#              </svg>
#             </button>
#             <!-- Voice selector -->
#             <div class="relative" id="tts-voice-wrap">
#              <button aria-label="Select voice" class="flex h-10 w-10 shrink-0 items-center justify-center rounded-full transition hover:bg-surface-l3 dark:hover:bg-white/10" id="tts-voice-btn" type="button">
#               <span class="h-6 w-6 rounded-full bg-gradient-to-br from-rose-500 via-purple-600 to-indigo-700" id="tts-voice-dot">
#               </span>
#              </button>
#              <div class="absolute bottom-full left-1/2 mb-2 w-44 -translate-x-1/2 overflow-hidden rounded-2xl border border-border-l2 bg-surface-l2 p-1 shadow-lg backdrop-blur dark:border-white/15 dark:bg-neutral-700/95 hidden" id="tts-voice-menu">
#               <button class="tts-voice-opt flex w-full items-center gap-3 rounded-xl px-3 py-2 text-left text-sm transition hover:bg-surface-l3 dark:text-white/80 dark:hover:bg-white/10" data-voice="human_Ara" type="button">
#                <span class="h-6 w-6 shrink-0 rounded-full bg-gradient-to-br from-rose-500 via-purple-600 to-indigo-700">
#                </span>
#                <span class="flex-1 font-semibold">
#                 Ara
#                </span>
#               </button>
#               <button class="tts-voice-opt flex w-full items-center gap-3 rounded-xl px-3 py-2 text-left text-sm transition hover:bg-surface-l3 dark:text-white/80 dark:hover:bg-white/10" data-voice="human_Eve" type="button">
#                <span class="h-6 w-6 shrink-0 rounded-full bg-gradient-to-br from-violet-500 via-fuchsia-600 to-purple-700">
#                </span>
#                <span class="flex-1 font-semibold">
#                 Eve
#                </span>
#               </button>
#               <button class="tts-voice-opt flex w-full items-center gap-3 rounded-xl px-3 py-2 text-left text-sm transition hover:bg-surface-l3 dark:text-white/80 dark:hover:bg-white/10" data-voice="human_Leo" type="button">
#                <span class="h-6 w-6 shrink-0 rounded-full bg-gradient-to-br from-red-500 via-orange-500 to-amber-600">
#                </span>
#                <span class="flex-1 font-semibold">
#                 Leo
#                </span>
#               </button>
#               <button class="tts-voice-opt flex w-full items-center gap-3 rounded-xl px-3 py-2 text-left text-sm transition hover:bg-surface-l3 dark:text-white/80 dark:hover:bg-white/10" data-voice="human_Sal" type="button">
#                <span class="h-6 w-6 shrink-0 rounded-full bg-gradient-to-br from-blue-600 via-cyan-500 to-sky-500">
#                </span>
#                <span class="flex-1 font-semibold">
#                 Sal
#                </span>
#               </button>
#              </div>
#             </div>
#             <!-- Waveform bars -->
#             <div aria-hidden="true" class="flex items-center gap-[3px] opacity-40" id="tts-bars">
#              <span class="w-1 rounded-full bg-fg-secondary/60 dark:bg-white/60" style="height:6px">
#              </span>
#              <span class="w-1 rounded-full bg-fg-secondary/60 dark:bg-white/60" style="height:3px">
#              </span>
#              <span class="w-1 rounded-full bg-fg-secondary/60 dark:bg-white/60" style="height:8px">
#              </span>
#              <span class="w-1 rounded-full bg-fg-secondary/60 dark:bg-white/60" style="height:4px">
#              </span>
#              <span class="w-1 rounded-full bg-fg-secondary/60 dark:bg-white/60" style="height:10px">
#              </span>
#              <span class="w-1 rounded-full bg-fg-secondary/60 dark:bg-white/60" style="height:5px">
#              </span>
#              <span class="w-1 rounded-full bg-fg-secondary/60 dark:bg-white/60" style="height:7px">
#              </span>
#              <span class="w-1 rounded-full bg-fg-secondary/60 dark:bg-white/60" style="height:3px">
#              </span>
#              <span class="w-1 rounded-full bg-fg-secondary/60 dark:bg-white/60" style="height:9px">
#              </span>
#              <span class="w-1 rounded-full bg-fg-secondary/60 dark:bg-white/60" style="height:4px">
#              </span>
#             </div>
#             <!-- Speed button -->
#             <button aria-label="Playback speed" class="flex h-10 shrink-0 items-center justify-center rounded-full px-2.5 text-xs font-bold tabular-nums text-fg-secondary transition hover:bg-surface-l3 dark:text-white/70 dark:hover:bg-white/10 sm:text-sm" id="tts-speed" type="button">
#              1x
#             </button>
#             <!-- Close -->
# ...
#       <div class="rounded-full bg-green-500/20 p-4">
#        <svg class="h-8 w-8 text-green-500" fill="none" stroke="currentColor" stroke-width="2" viewbox="0 0 24 24">
#         <path d="M5 13l4 4L19 7" stroke-linecap="round" stroke-linejoin="round">
#         </path>
#        </svg>
#       </div>
#      </div>
#      <h3 class="text-xl font-semibold text-fg-primary mb-2">
#       Thank you!
#      </h3>
#      <p class="text-sm text-fg-secondary mb-6" id="contribute-success-msg">
#       Grok will review your suggestion and add the article if it sees fit.
#      </p>
#      <div class="flex flex-col gap-3">
#       <a class="w-full rounded-lg bg-fg-primary px-4 py-2.5 text-sm font-medium text-surface-base transition hover:opacity-90" href="/activity">
#        View my suggestions
#       </a>
#       <button class="w-full rounded-lg border border-border-l1 px-4 py-2.5 text-sm font-medium text-fg-secondary transition hover:bg-surface-l2" data-submit-another="" type="button">
#        Submit another suggestion
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script nonce="9Y/jJR93aRXgpMCoBIpWeg==">
#    (function(){
#       var isAuth = document.body.getAttribute('data-auth') === '1';
#       var accountUrl = 'https://accounts.x.ai';
#       var currentPath = window.location.pathname + window.location.search;
#       var signInUrl = accountUrl + '/check-login?redirect=grokipedia-com&return_to=' + encodeURIComponent(currentPath);
#
#       // Sign-in modal for logged-out users
#       var signinBackdrop = document.getElementById('signin-backdrop');
#       var signinModal = document.getElementById('signin-modal');
#       var signinBtn = document.getElementById('signin-modal-btn');
#
#       if (signinBtn) signinBtn.href = signInUrl;
#
#       function openSigninModal() {
#         if (!signinBackdrop || !signinModal) return;
#         signinBackdrop.classList.remove('hidden');
#         signinModal.classList.remove('hidden');
#         document.body.style.overflow = 'hidden';
#       }
#
#       function closeSigninModal() {
#         if (!signinBackdrop || !signinModal) return;
#         signinBackdrop.classList.add('hidden');
#         signinModal.classList.add('hidden');
#         document.body.style.overflow = '';
#       }
#
#       if (signinBackdrop) signinBackdrop.addEventListener('click', closeSigninModal);
#       if (signinModal) {
#         signinModal.addEventListener('click', function(e) {
#           if (e.target === signinModal) closeSigninModal();
#         });
#         document.addEventListener('keydown', function(e) {
#           if (e.key === 'Escape' && !signinModal.classList.contains('hidden')) closeSigninModal();
#         });
#       }
#
#       var backdrop = document.getElementById('contribute-backdrop');
#       var modal = document.getElementById('contribute-modal');
#       if (!backdrop || !modal) return;
#
#       var pageSlug = modal.getAttribute('data-page-slug') || '';
#       var currentMode = 'article';
#
#       var titleEl = document.getElementById('contribute-title');
#       var descEl = document.getElementById('contribute-desc');
#       var tabsContainer = document.getElementById('contribute-tabs');
#       var articleForm = document.getElementById('contribute-article-form');
#       var editForm = document.getElementById('contribute-edit-form');
#       var editFields = document.getElementById('contribute-edit-fields');
#       var statusEl = modal.querySelector('[data-contribute-status]');
#       var tabBtns = modal.querySelectorAll('[data-tab]');
#
#       var articleTopic = modal.querySelector('[data-article-topic]');
#       var articleDesc = modal.querySelector('[data-article-desc]');
#       var articleTopicCount = modal.querySelector('[data-article-topic-count]');
#       var articleDescCount = modal.querySelector('[data-article-desc-count]');
#       var articleSubmit = modal.querySelector('[data-article-submit]');
#
#       var editSummary = modal.querySelector('[data-edit-summary]');
#       var editSummaryCount = modal.querySelector('[data-edit-summary-count]');
#       var editProposed = modal.querySelector('[data-edit-proposed]');
#       var editSubmit = modal.querySelector('[data-edit-submit]');
#       var editEvidenceList = modal.querySelector('[data-edit-evidence-list]');
#       var successState = document.getElementById('contribute-success');
#       var successMsg = document.getElementById('contribute-success-msg');
#       var errorState = document.getElementById('contribute-error');
#       var errorMsg = document.getElementById('contribute-error-msg');
#       var submitAnotherBtn = modal.querySelector('[data-submit-another]');
#       var tryAgainBtn = modal.querySelector('[data-try-again]');
#
#       var editContext = { originalContent: '', sectionTitle: '', editStartHeader: '', editEndHeader: '' };
#
#       function setMode(mode) {
#         currentMode = mode;
#         tabBtns.forEach(function(btn) {
#           var isActive = btn.getAttribute('data-tab') === mode;
#           btn.classList.toggle('bg-surface-base', isActive);
#           btn.classList.toggle('text-fg-primary', isActive);
#           btn.classList.toggle('shadow-sm', isActive);
#           btn.classList.toggle('text-fg-tertiary', !isActive);
#         });
#         articleForm.classList.toggle('hidden', mode !== 'article');
#         editForm.classList.toggle('hidden', mode !== 'edit');
#         successState.classList.add('hidden');
#         statusEl.classList.add('hidden');
#         titleEl.textContent = mode === 'article' ? 'Suggest an article' : 'Suggest an edit';
#         descEl.textContent = mode === 'article'
#           ? 'Know something the world should know? Tell us what to write about.'
#           : 'Spotted something off? Help us get it right.';
#       }
#
#       function showSuccessState() {
#         articleForm.classList.add('hidden');
#         editForm.classList.add('hidden');
#         tabsContainer.classList.add('hidden');
#         titleEl.classList.add('hidden');
#         descEl.classList.add('hidden');
#         statusEl.classList.add('hidden');
#         errorState.classList.add('hidden');
#         // Set appropriate message based on mode
#         if (currentMode === 'edit') {
#           successMsg.textContent = 'Grok will review your edit and update the article if appropriate.';
#         } else {
#           successMsg.textContent = 'Grok will review your suggestion and add the article if it sees fit.';
#         }
#         successState.classList.remove('hidden');
#       }
#
#       function showErrorState(message) {
#         articleForm.classList.add('hidden');
#         editForm.classList.add('hidden');
#         tabsContainer.classList.add('hidden');
#         titleEl.classList.add('hidden');
#         descEl.classList.add('hidden');
#         statusEl.classList.add('hidden');
#         successState.classList.add('hidden');
#         var defaultMsg = currentMode === 'edit'
#           ? "We couldn't submit your edit. Please try again."
#           : "We couldn't submit your suggestion. Please try again.";
#         errorMsg.textContent = message || defaultMsg;
#         errorState.classList.remove('hidden');
#       }
#
#       function resetToForm() {
#         successState.classList.add('hidden');
#         errorState.classList.add('hidden');
#         titleEl.classList.remove('hidden');
#         descEl.classList.remove('hidden');
#         if (pageSlug) tabsContainer.classList.remove('hidden');
#         setMode(currentMode);
#         // Clear form fields
#         articleTopic.value = '';
#         articleDesc.value = '';
#         if (articleTopicCount) articleTopicCount.textContent = '0';
#         if (articleDescCount) articleDescCount.textContent = '0';
#         editSummary.value = '';
#         if (editSummaryCount) editSummaryCount.textContent = '0';
#         editProposed.value = '';
#         // Reset evidence fields to single empty input
#         if (editEvidenceList) {
#           editEvidenceList.innerHTML = '<input type="url" data-edit-evidence placeholder="https://example.com/source" class="w-full rounded-lg border border-border-l1 bg-surface-base px-4 py-2.5 text-sm text-fg-primary placeholder:text-fg-tertiary focus:border-fg-secondary focus:outline-none" />';
#         }
#         // Reset buttons
#         articleSubmit.disabled = true;
#         articleSubmit.textContent = 'Submit';
#         editSubmit.disabled = true;
#         editSubmit.textContent = 'Submit Edit';
#         if (currentMode === 'article') {
#           articleTopic.focus();
#         } else {
#           editSummary.focus();
#         }
#       }
#
#       if (submitAnotherBtn) {
#         submitAnotherBtn.addEventListener('click', resetToForm);
#       }
#
#       if (tryAgainBtn) {
#         tryAgainBtn.addEventListener('click', resetToForm);
#       }
#
#       tabBtns.forEach(function(btn) {
#         btn.addEventListener('click', function() { setMode(btn.getAttribute('data-tab')); });
#       });
#
#       function openModal(options) {
#         options = options || {};
#         var mode = options.mode || (pageSlug ? 'edit' : 'article');
#         articleTopic.value = options.initialTopic || '';
#         articleDesc.value = '';
#         articleTopicCount.textContent = '';
#         articleDescCount.textContent = '';
#         articleSubmit.disabled = true;
#         articleSubmit.textContent = 'Submit';
#
#         editSummary.value = '';
#         editSummaryCount.textContent = '';
#         editProposed.value = options.selectedText || '';
#         editSubmit.disabled = true;
#         editSubmit.textContent = 'Submit Edit';
#         editEvidenceList.innerHTML = '<input data-edit-evidence type="url" placeholder="https://example.com/source" class="w-full rounded-lg border border-border-l1 bg-surface-base px-3 py-2.5 text-sm text-fg-primary placeholder:text-fg-tertiary focus:border-blue-500 focus:outline-none" />';
#         editContext = {
#           originalContent: options.selectedText || '',
#           sectionTitle: options.sectionTitle || '',
#           editStartHeader: options.editStartHeader || '',
#           editEndHeader: options.editEndHeader || '',
#         };
#
#         statusEl.classList.add('hidden');
#         successState.classList.add('hidden');
#         errorState.classList.add('hidden');
#         titleEl.classList.remove('hidden');
#         descEl.classList.remove('hidden');
#
#         if (pageSlug) {
#           tabsContainer.classList.remove('hidden');
#         } else {
#           tabsContainer.classList.add('hidden');
#           mode = 'article';
#         }
#
#         setMode(mode);
#         backdrop.classList.remove('hidden');
#         modal.classList.remove('hidden');
#         document.body.style.overflow = 'hidden';
#         if(window.__ev)window.__ev(mode === 'edit' ? 'edit_open' : 'suggest_open');
#
#         if (mode === 'article') articleTopic.focus();
#         else editSummary.focus();
#       }
#
#       function closeModal() {
#         backdrop.classList.add('hidden');
#         modal.classList.add('hidden');
#         document.body.style.overflow = '';
#       }
#
#       window.__openSuggestArticle = function(initialTopic) {
#         if (!isAuth) { openSigninModal(); return; }
#         openModal({ mode: 'article', initialTopic: initialTopic });
#       };
#       window.__openContributeModal = function(options) {
#         if (!isAuth) { openSigninModal(); return; }
#         openModal(options);
#       };
#
#       backdrop.addEventListener('click', closeModal);
#       modal.addEventListener('click', function(e) { if (!e.target.closest('[data-contribute-inner]')) closeModal(); });
#       modal.querySelector('[data-contribute-close]').addEventListener('click', closeModal);
#       modal.querySelectorAll('[data-contribute-cancel]').forEach(function(btn) { btn.addEventListener('click', closeModal); });
#       document.addEventListener('keydown', function(e) {
#         if (e.key === 'Escape' && !modal.classList.contains('hidden')) closeModal();
#       });
#
#       function updateArticleCounters() {
#         var tl = articleTopic.value.length;
#         articleTopicCount.textContent = tl > 0 ? (50 - tl) : '';
#         var dl = articleDesc.value.length;
#         articleDescCount.textContent = dl > 0 ? (5000 - dl) : '';
#         articleSubmit.disabled = !articleTopic.value.trim() && !articleDesc.value.trim();
#       }
#       articleTopic.addEventListener('input', updateArticleCounters);
#       articleDesc.addEventListener('input', updateArticleCounters);
#
#       function updateEditCounters() {
#         var len = editSummary.value.length;
#         editSummaryCount.textContent = len > 0 ? (1500 - len) : '';
#         editSubmit.disabled = len === 0 || len > 1500;
#       }
#       editSummary.addEventListener('input', updateEditCounters);
#
#       modal.querySelector('[data-edit-add-evidence]').addEventListener('click', function() {
#         if (editEvidenceList.querySelectorAll('[data-edit-evidence]').length >= 10) return;
#         var inp = document.createElement('input');
#         inp.setAttribute('data-edit-evidence', '');
#         inp.type = 'url';
#         inp.placeholder = 'https://example.com/source';
#         inp.className = 'w-full rounded-lg border border-border-l1 bg-surface-base px-3 py-2.5 text-sm text-fg-primary placeholder:text-fg-tertiary focus:border-blue-500 focus:outline-none';
#         editEvidenceList.appendChild(inp);
#         inp.focus();
#       });
#
#       articleForm.addEventListener('submit', function(e) {
#         e.preventDefault();
#         var title = articleTopic.value.trim();
#         var description = articleDesc.value.trim();
#         if (!title && !description) return;
#         articleSubmit.disabled = true;
#         articleSubmit.textContent = 'Submitting...';
#         statusEl.classList.add('hidden');
#
#         fetch('/api/create-article-request', {
#           method: 'POST',
#           headers: { 'Content-Type': 'application/json' },
#           credentials: 'same-origin',
#           body: JSON.stringify({ title: title, description: description })
#         })
#         .then(function(r) { return r.json().then(function(d) { return { ok: r.ok, data: d }; }); })
#         .then(function(res) {
#           if (res.ok && res.data.success) {
#             if(window.__ev)window.__ev('suggest_submit');
#             showSuccessState();
#           } else {
#             showErrorState(res.data.error || "We couldn't submit your suggestion. Please try again.");
#           }
#         })
#         .catch(function() {
#           showErrorState("Network error. Please check your connection and try again.");
#         });
#       });
#
#       editForm.addEventListener('submit', function(e) {
#         e.preventDefault();
#         var summary = editSummary.value.trim();
#         if (!summary || !pageSlug) return;
#         if(window.__ev)window.__ev('edit_submit', pageSlug);
#         editSubmit.disabled = true;
#         editSubmit.textContent = 'Submittingâ¦';
#         statusEl.classList.add('hidden');
#
#         var evidence = [];
#         editEvidenceList.querySelectorAll('[data-edit-evidence]').forEach(function(inp) {
#           var url = inp.value.trim();
#           if (url) evidence.push({ url: url });
#         });
#
#         fetch('/api/create-edit-request', {
#           method: 'POST',
#           headers: { 'Content-Type': 'application/json' },
#           credentials: 'same-origin',
#           body: JSON.stringify({
#             slug: pageSlug,
#             type: 1,
#             summary: summary,
#             originalContent: editContext.originalContent,
#             proposedContent: editProposed.value.trim(),
#             sectionTitle: editContext.sectionTitle,
#             editStartHeader: editContext.editStartHeader,
#             editEndHeader: editContext.editEndHeader,
#             supportingEvidence: evidence,
#           })
#         })
#         .then(function(r) { return r.json().then(function(d) { return { ok: r.ok, data: d }; }); })
#         .then(function(res) {
#           if (res.ok && res.data.success) {
#             showSuccessState();
#           } else {
#             showErrorState(res.data.error || "We couldn't submit your edit. Please try again.");
#           }
#         })
#         .catch(function() {
#           showErrorState("Network error. Please check your connection and try again.");
#         });
#       });
#     })();
#   </script>
#  </body>
# </html>

# %%
soup.find_all('table')[1]
# Out:
# <table class="w-full border-collapse text-sm"><thead class="border-border-l1 border-b bg-surface-l1"><tr class="divide-border-l1 divide-x bg-surface-l1"><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Rank</span></th><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Company Name</span></th><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Net Profit ($B)</span></th><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Revenue ($B)</span></th><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Industry</span></th><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Headquarters</span></th></tr>
# </thead><tbody class="divide-border-l1 divide-y"><tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">1</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Alphabet Inc.</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">124.3</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">385.5</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Communication Services</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Mountain View, CA</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">2</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Apple Inc.</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">112.0</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">416.2</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Information Technology</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Cupertino, CA</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">3</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Microsoft Corporation</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">104.9</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">293.8</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Information Technology</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Redmond, WA</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">4</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]
span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Houston, TX</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">42</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Altria Group Inc.</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">8.8</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">23.4</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Consumer Staples</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Richmond, VA</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">43</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Philip Morris International Inc.</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">8.6</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">40.0</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Consumer Staples</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Stamford, CT</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">44</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Micron Technology Inc.</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">8.5</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">37.4</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Information Technology</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Boise, ID</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">45</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">McDonald's Corporation</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">8.4</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">26.3</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Consumer Discretionary</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Chicago, IL</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">46</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Gilead Sciences Inc.</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">8.1</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">29.1</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Health Care</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Foster City, CA</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">47</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Costco Wholesale Corporation</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">8.1</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">275.2</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Consumer Staples</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Issaquah, WA</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">48</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">General Electric Company</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">8.1</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">43.9</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Industrials</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Boston, MA</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">49</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">International Business Machines Corporation</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">7.9</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">65.4</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Information Technology</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Armonk, NY</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">50</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">MicroStrategy Incorporated</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">7.7</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">0.5</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Information Technology</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Tysons Corner, VA</span></td></tr>
# </tbody></table>

# %%
table2 = soup.find_all('table')[1]

# %%
table2.find_all('th')
# Out:
# [<th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Rank</span></th>,
#  <th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Company Name</span></th>,
#  <th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Net Profit ($B)</span></th>,
#  <th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Revenue ($B)</span></th>,
#  <th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Industry</span></th>,
#  <th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Headquarters</span></th>]

# %%
table_header = table2.find_all('th')

# %%
world_table_header = [title.text for title in table_header]

# %%
world_table_header
# Out:
# ['Rank',
#  'Company Name',
#  'Net Profit ($B)',
#  'Revenue ($B)',
#  'Industry',
#  'Headquarters']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_header)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Rank, Company Name, Net Profit ($B), Revenue ($B), Industry, Headquarters]
# Index: []

# %%
column_data = table2.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#    Rank                                 Company Name Net Profit ($B)  \
# 0     1                                Alphabet Inc.           124.3
# 1     2                                   Apple Inc.           112.0
# 2     3                        Microsoft Corporation           104.9
# 3     4                           NVIDIA Corporation            86.6
# 4     5                              Amazon.com Inc.            76.5
# 5     6                      Berkshire Hathaway Inc.            67.5
# 6     7                          Meta Platforms Inc.            58.5
# 7     8                         JPMorgan Chase & Co.            56.7
# 8     9                      Exxon Mobil Corporation            30.0
# 9    10                  Bank of America Corporation            28.3
# 10   11                            Johnson & Johnson            25.1
# 11   12                          Comcast Corporation            22.6
# 12   13                                    AT&T Inc.            22.2
# 13   14                                 Walmart Inc.            21.3
# 14   15                        Wells Fargo & Company            20.0
# 15   16                                    Visa Inc.            19.9
# 16   17                  Verizon Communications Inc.            19.8
# 17   18                                Broadcom Inc.            18.9
# 18   19                        Eli Lilly and Company            18.4
# 19   20              UnitedHealth Group Incorporated            17.6
# 20   21                       Uber Technologies Inc.            16.6
# 21   22                     Procter & Gamble Company            16.5
# 22   23                             Merck & Co. Inc.            16.4
# 23   24                     Goldman Sachs Group Inc.            15.8
# 24   25                              Home Depot Inc.            14.6
# 25   26                      Mastercard Incorporated            14.3
# 26   27                               Morgan Stanley            14.1
# 27   28                          Abbott Laboratories            14.0
# 28   29                          Chevron Corporation            13.7
# 29   30                               Citigroup Inc.            13.4
# 30   31                            Coca-Cola Company            13.0
# 31   32                           Oracle Corporation            12.4
# 32   33                             T-Mobile US Inc.            11.9
# 33   34                          Walt Disney Company            11.6
# 34   35                      Progressive Corporation            10.7
# 35   36                                 Netflix Inc.            10.4
# 36   37                     American Express Company            10.4
# 37   38                           Cisco Systems Inc.            10.2
# 38   39                                  Pfizer Inc.             9.8
# 39   40                             Caterpillar Inc.             9.3
# 40   41                               ConocoPhillips             9.2
# 41   42                            Altria Group Inc.             8.8
# 42   43             Philip Morris International Inc.             8.6
# 43   44                       Micron Technology Inc.             8.5
# 44   45                       McDonald's Corporation             8.4
# 45   46                         Gilead Sciences Inc.             8.1
# 46   47                 Costco Wholesale Corporation             8.1
# 47   48                     General Electric Company             8.1
# 48   49  International Business Machines Corporation             7.9
# 49   50                   MicroStrategy Incorporated             7.7
#
#    Revenue ($B)                Industry          Headquarters
# 0         385.5  Communication Services     Mountain View, CA
# 1         416.2  Information Technology         Cupertino, CA
# 2         293.8  Information Technology           Redmond, WA
# 3         165.2  Information Technology       Santa Clara, CA
# 4         691.3  Consumer Discretionary           Seattle, WA
# 5         372.1              Financials             Omaha, NE
# 6         189.5  Communication Services        Menlo Park, CA
# 7         277.7              Financials          New York, NY
# 8         324.9                  Energy            Irving, TX
# 9         188.8              Financials         Charlotte, NC
# 10         92.1             Health Care     New Brunswick, NJ
# 11        123.3  Communication Services      Philadelphia, PA
# 12        124.5  Communication Services            Dallas, TX
# 13        693.2        Consumer Staples       Bentonville, AR
# 14        122.6              Financials     San Francisco, CA
# 15         40.0              Financials     San Francisco, CA
# 16        137.5  Communication Services          New York, NY
# 17         59.9  Information Technology         Palo Alto, CA
# 18         59.4             Health Care      Indianapolis, IN
# 19        435.2             Health Care        Minnetonka, MN
# 20         49.6             Industrials     San Francisco, CA
# 21         84.9        Consumer Staples        Cincinnati, OH
# 22         63.6             Health Care            Rahway, NJ
# 23        127.2              Financials          New York, NY
# 24        165.1  Consumer Discretionary           Atlanta, GA
# 25         31.5              Financials          Purchase, NY
# 26        113.0              Financials          New York, NY
# 27         43.8             Health Care           Chicago, IL
# 28        187.7                  Energy         San Ramon, CA
# 29        168.3              Financials          New York, NY
# 30         47.7        Consumer Staples           Atlanta, GA
# 31         59.0  Information Technology            Austin, TX
# 32         85.8  Communication Services          Bellevue, WA
# 33         94.5  Communication Services           Burbank, CA
# 34         85.2              Financials  Mayfield Village, OH
# 35         43.4  Communication Services         Los Gatos, CA
# 36         75.9              Financials          New York, NY
# 37         56.7  Information Technology          San Jose, CA
# 38         62.8             Health Care          New York, NY
# 39         64.7             Industrials         Deerfield, IL
# 40         57.8                  Energy           Houston, TX
# 41         23.4        Consumer Staples          Richmond, VA
# 42         40.0        Consumer Staples          Stamford, CT
# 43         37.4  Information Technology             Boise, ID
# 44         26.3  Consumer Discretionary           Chicago, IL
# 45         29.1             Health Care       Foster City, CA
# 46        275.2        Consumer Staples          Issaquah, WA
# 47         43.9             Industrials            Boston, MA
# 48         65.4  Information Technology            Armonk, NY
# 49          0.5  Information Technology     Tysons Corner, VA

# %%
soup.find_all('table')[0]
# Out:
# <table class="w-full border-collapse text-sm"><thead class="border-border-l1 border-b bg-surface-l1"><tr class="divide-border-l1 divide-x bg-surface-l1"><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Rank</span></th><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Company Name</span></th><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Revenue ($B)</span></th><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Industry</span></th><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Headquarters State</span></th><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">CEO</span></th></tr>
# </thead><tbody class="divide-border-l1 divide-y"><tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">1</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Walmart</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">681</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Retail</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Arkansas</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Doug McMillon</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">2</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Amazon</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">638</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">E-commerce</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Washington</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Andy Jassy</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">3</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">UnitedHealth Group</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">400</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Healthcare</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Minnesota</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Andrew Witty</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">4</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Apple</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">391</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Technology</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">California</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Tim Cook</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">5</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">CVS Health</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">373</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Healthcare</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Rhode Island</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Karen S. Lynch</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">6</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Berkshire Hathaway</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">371</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Conglomerate</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Nebraska</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Warren Buffett</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">7</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Alphabet</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">350</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Technology</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">California</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Sundar Pichai</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">8</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">ExxonMobil</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">350</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Energy</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Texas</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Darren Woods</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">9</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">McKesson</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">309</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Healthcare</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Texas</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Brian Tyler</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">10</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Cencora</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">294</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Healthcare</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Pennsylvania</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Steven H. Collis</span></td></tr>
# </tbody></table>

# %%
table1 = soup.find_all('table')[0]

# %%
table1.find_all('th')
# Out:
# [<th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Rank</span></th>,
#  <th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Company Name</span></th>,
#  <th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Revenue ($B)</span></th>,
#  <th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Industry</span></th>,
#  <th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Headquarters State</span></th>,
#  <th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">CEO</span></th>]

# %%
table_header1 = table1.find_all('th')

# %%
world_table_header1 = [title.text for title in table_header1]

# %%
world_table_header1
# Out:
# ['Rank',
#  'Company Name',
#  'Revenue ($B)',
#  'Industry',
#  'Headquarters State',
#  'CEO']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_header1)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Rank, Company Name, Revenue ($B), Industry, Headquarters State, CEO]
# Index: []

# %%
column_data1 = table1.find_all('tr')

# %%
for row in column_data1[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#   Rank        Company Name Revenue ($B)      Industry Headquarters State  \
# 0    1             Walmart          681        Retail           Arkansas
# 1    2              Amazon          638    E-commerce         Washington
# 2    3  UnitedHealth Group          400    Healthcare          Minnesota
# 3    4               Apple          391    Technology         California
# 4    5          CVS Health          373    Healthcare       Rhode Island
# 5    6  Berkshire Hathaway          371  Conglomerate           Nebraska
# 6    7            Alphabet          350    Technology         California
# 7    8          ExxonMobil          350        Energy              Texas
# 8    9            McKesson          309    Healthcare              Texas
# 9   10             Cencora          294    Healthcare       Pennsylvania
#
#                 CEO
# 0     Doug McMillon
# 1        Andy Jassy
# 2      Andrew Witty
# 3          Tim Cook
# 4    Karen S. Lynch
# 5    Warren Buffett
# 6     Sundar Pichai
# 7      Darren Woods
# 8       Brian Tyler
# 9  Steven H. Collis

# %%
soup.find_all('table')[2]
# Out:
# <table class="w-full border-collapse text-sm"><thead class="border-border-l1 border-b bg-surface-l1"><tr class="divide-border-l1 divide-x bg-surface-l1"><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Rank</span></th><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Company Name</span></th><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Estimated Revenue ($B USD)</span></th><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Industry</span></th><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Headquarters State</span></th><th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Founder/Owner</span></th></tr>
# </thead><tbody class="divide-border-l1 divide-y"><tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">1</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/Cargill">Cargill</a></span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">160</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/Agriculture">Agriculture</a></span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/Minnesota">Minnesota</a></span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/Cargill_family">Cargill family</a></span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">2</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Koch Industries</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">125</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Diversified</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/Kansas">Kansas</a></span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/Koch_family">Koch family</a></span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">3</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/Publix">Publix</a> Super Markets</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">57.1</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Retail</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/Florida">Florida</a></span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Employee-owned</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">4</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Mars</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">50</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Food</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Virginia</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/Mars_family">Mars family</a></span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">5</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/H-E-B">H-E-B</a></span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">46.5</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Retail</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/Texas">Texas</a></span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Butt family</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">6</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/Reyes_Holdings">Reyes Holdings</a></span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">40</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Distribution</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/Illinois">Illinois</a></span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Reyes family</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">7</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Enterprise Mobility</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">38</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Transportation</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/Missouri">Missouri</a></span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Taylor family</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">8</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/C&amp;S_Wholesale_Grocers">C&amp;S Wholesale Grocers</a></span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">34</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Wholesale</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/New_Hampshire">New Hampshire</a></span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Cohen family</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">9</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/Fidelity_Investments">Fidelity Investments</a></span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">28.2</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Finance</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/Massachusetts">Massachusetts</a></span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Johnson family</span></td></tr>
# <tr class="divide-border-l1 divide-x bg-surface-l1"><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">10</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Southern Glazer's Wine &amp; Spirits</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">26</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]">Distribution</span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/Florida">Florida</a></span></td><td class="text-fg-primary px-2 py-1 align-top"><span class="text-[1em] leading-[1.85]"><a class="break-words text-[1em] text-blue-500 hover:underline dark:text-blue-200" href="/page/Chaplin_family">Chaplin family</a></span></td></tr>
# </tbody></table>

# %%
table3 = soup.find_all('table')[2]

# %%
table3.find_all('th')
# Out:
# [<th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Rank</span></th>,
#  <th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Company Name</span></th>,
#  <th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Estimated Revenue ($B USD)</span></th>,
#  <th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Industry</span></th>,
#  <th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Headquarters State</span></th>,
#  <th class="dark:text-fg-primary bg-gray-100 px-2 py-1 text-left align-top font-bold dark:bg-black"><span class="text-[1em] leading-[1.85]">Founder/Owner</span></th>]

# %%
table_header3 = table3.find_all('th')

# %%
world_title_header3 = [title.text for title in table_header3]

# %%
world_title_header3
# Out:
# ['Rank',
#  'Company Name',
#  'Estimated Revenue ($B USD)',
#  'Industry',
#  'Headquarters State',
#  'Founder/Owner']

# %%
import pandas as pd

df = pd.DataFrame(columns = world_title_header3)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Rank, Company Name, Estimated Revenue ($B USD), Industry, Headquarters State, Founder/Owner]
# Index: []

# %%
column_data3 = table3.find_all('td')

# %%
for row in column_data3[1:]:
    row_data in row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#    Rank Company Name Estimated Revenue ($B USD)    Industry  \
# 0    10      Cencora                        294  Healthcare
# 1    10      Cencora                        294  Healthcare
# 2    10      Cencora                        294  Healthcare
# 3    10      Cencora                        294  Healthcare
# 4    10      Cencora                        294  Healthcare
# ..  ...          ...                        ...         ...
# 64   10      Cencora                        294  Healthcare
# 65   10      Cencora                        294  Healthcare
# 66   10      Cencora                        294  Healthcare
# 67   10      Cencora                        294  Healthcare
# 68   10      Cencora                        294  Healthcare
#
#    Headquarters State     Founder/Owner
# 0        Pennsylvania  Steven H. Collis
# 1        Pennsylvania  Steven H. Collis
# 2        Pennsylvania  Steven H. Collis
# 3        Pennsylvania  Steven H. Collis
# 4        Pennsylvania  Steven H. Collis
# ..                ...               ...
# 64       Pennsylvania  Steven H. Collis
# 65       Pennsylvania  Steven H. Collis
# 66       Pennsylvania  Steven H. Collis
# 67       Pennsylvania  Steven H. Collis
# 68       Pennsylvania  Steven H. Collis
#
# [69 rows x 6 columns]
